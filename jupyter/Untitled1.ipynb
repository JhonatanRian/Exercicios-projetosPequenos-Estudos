# %%
from time import sleep
import pyautogui as auto
from selenium import webdriver
from selenium.webdriver.common.by import By
auto.PAUSE = 2.5

# %%
url: str = "https://www.bet365.com/#/HO/"
driver = webdriver.Firefox()

# %%
driver.get(url)

# %%
element = driver.find_elements(By.TAG_NAME, "div")
for el in element:
    if el.text == "Login":
        var = el
        break
var.click()

# %%
element = driver.find_elements(By.TAG_NAME ,"input")
for el in element:
    if el.get_attribute("placeholder") == "Usuário":
        el.send_keys("JhonatanRian")
        break
for el in element:
    if el.get_attribute("placeholder") == "Senha":
        el.send_keys("j1f5e3o3")
        break

# %%
element = driver.find_element(By.CLASS_NAME ,"lms-StandardLogin_LoginButton ")
element.click()

# %%
# hm-MainHeaderLHSNarrow_AZIcon 
element = driver.find_elements(By.TAG_NAME, "div")
for el in element:
    if el.get_attribute("class") == "hm-MainHeaderLHSNarrow_AZIcon ":
        el.click()
        break

# %%
element = driver.find_elements(By.TAG_NAME, "input")
for el in element:
    if el.get_attribute("class") == "wn-SiteSearch_SearchInput ":
        el.click()
        ell = el
        break

# %%
ell.send_keys("flamengo")
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-25-9a5926525302> in <module>
# ----> 1 ell.send_keys("flamengo")
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in send_keys(self, *value)
#     475                 value = self._upload(local_file)
#     476
# --> 477         self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     478                       {'text': "".join(keys_to_typing(value)),
#     479                        'value': keys_to_typing(value)})
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: Element <input class="wn-SiteSearch_SearchInput " type="text"> is not reachable by keyboard

# %%
# wn-SiteSearch_SearchInput 
element = driver.find_elements(By.TAG_NAME, "div")
for el in element:
    if el.get_attribute("class") == "hm-MainHeaderMembersWide_MembersMenuIcon ":
        el.click()
        break
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-14-0b008d62090d> in <module>
#       3 for el in element:
#       4     if el.get_attribute("class") == "hm-MainHeaderMembersWide_MembersMenuIcon ":
# ----> 5         el.click()
#       6         break
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: Element <div class="hm-MainHeaderMembersWide_MembersMenuIcon "> could not be scrolled into view

# %%
element = driver.find_elements(By.TAG_NAME, "span")
for el in element:
    if el.get_attribute("class") == "um-UserInfo_UserName ":
        print(True)
        break

# %%
element = driver.find_elements(By.TAG_NAME, "div")
for el in element:
    if el.get_attribute("class") == "hm-SiteSearchIconLoggedIn ":
        el.click()
        break

# %%
# sml-SearchTextInput 
element = driver.find_elements(By.TAG_NAME, "input")
for el in element:
    if el.get_attribute("class") == "sml-SearchTextInput ":
        var = el
        break
var.send_keys("Flamengo")

# %%
lista_jogos = list()
element = driver.find_elements(By.TAG_NAME, "div")
for el in element:
    if el.get_attribute("class") == "ssm-SiteSearchLabelOnlyParticipant gl-Market_General-cn1 ":
        jogo = el.find_element(By.TAG_NAME ,"span")
        lista_jogos.append(jogo)

# %%
lista_jogos[1].click()

# %%
element = driver.find_elements(By.TAG_NAME, "div")
elemento_time = None
for elem in element:
    if elem.get_attribute("class") == "gl-MarketGroup ":
        elemento = elem
        break

# %%
lista = elemento.find_elements(By.TAG_NAME, "div")
for l in lista:
    if l.get_attribute("class") == "gl-Participant gl-Participant_General gl-Market_General-cn3 ":
        if "Flamengo" in l.text:
            time_aposta = l
            break
time_aposta.click()

# %%
c = auto.getWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-3324fa2027a3> in <module>
# ----> 1 c = auto.getWindows()
#       2 print(c)
#
# AttributeError: module 'pyautogui' has no attribute 'getWindows'

# %%
element = driver.find_elements(By.TAG_NAME, "div")
for elem in element:
    if elem.get_attribute("class") == "qbs-StakeBox_StakeInput ":
        butao_valor = elem
        break
butao_valor.click()
butao_valor.send_keys("10")
# position (422,566)
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-99-87f2b94a3540> in <module>
#       5         break
#       6 butao_valor.click()
# ----> 7 butao_valor.send_keys("10")
#       8 # position (422,566)
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in send_keys(self, *value)
#     475                 value = self._upload(local_file)
#     476
# --> 477         self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     478                       {'text': "".join(keys_to_typing(value)),
#     479                        'value': keys_to_typing(value)})
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: Element <div class="qbs-StakeBox_StakeInput "> is not reachable by keyboard

# %%
# qbs-NormalBetItem_DetailsContainer 
#qbs-StakeBox_StakeAmount 
#qbs-StakeBox_StakeValue-wrapper 
element = driver.find_elements(By.TAG_NAME, "div")
for elem in element:
    if elem.get_attribute("class") == "qbs-StakeBox_StakeValue-wrapper ":
        print(True)
        el = elem
l = el.find_element(By.TAG_NAME, "input")
l.send_keys("10")
# Out:
# True
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-104-a9f487f7ec84> in <module>
#       7         print(True)
#       8         el = elem
# ----> 9 l = el.find_element(By.TAG_NAME, "input")
#      10 l.send_keys("10")
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in find_element(self, by, value)
#     656                 value = '[name="%s"]' % value
#     657
# --> 658         return self._execute(Command.FIND_CHILD_ELEMENT,
#     659                              {"using": by, "value": value})['value']
#     660
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: Unable to locate element: input
